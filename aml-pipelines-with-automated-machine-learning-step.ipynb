# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-132181
# aml-quickstarts-132181
# southcentralus
# b968fb36-f06a-4c76-a15f-afab68ae7667

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'operationalizing-ml'
project_folder = './'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: operationalizing-ml,
# Workspace: quick-starts-ws-132181)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "auto-ml"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',
                                                           min_nodes=1,
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Creating
# Succeeded.......................
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 60,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'Accuracy'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             model_explainability= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [96dec778][9c6a630b-2058-4bfa-94fd-e37de4dafad5], (This step will run and generate new outputs)
# Submitted PipelineRun 5791282c-1eef-41a6-9255-d57efda530b0
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/operationalizing-ml/runs/5791282c-1eef-41a6-9255-d57efda530b0?wsid=/subscriptions/b968fb36-f06a-4c76-a15f-afab68ae7667/resourcegroups/aml-quickstarts-132181/workspaces/quick-starts-ws-132181

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# WARNING:azureml.pipeline.core.run:Expected a StepRun object but received <class 'azureml.core.run.Run'> instead.
# This usually indicates a package conflict with one of the dependencies of azureml-core or azureml-pipeline-core.
# Please check for package conflicts in your python environment
# PipelineRunId: 5791282c-1eef-41a6-9255-d57efda530b0
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/operationalizing-ml/runs/5791282c-1eef-41a6-9255-d57efda530b0?wsid=/subscriptions/b968fb36-f06a-4c76-a15f-afab68ae7667/resourcegroups/aml-quickstarts-132181/workspaces/quick-starts-ws-132181
# PipelineRun Status: Running
#
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '5791282c-1eef-41a6-9255-d57efda530b0', 'status': 'Completed', 'startTimeUtc': '2020-12-28T16:00:48.02894Z', 'endTimeUtc': '2020-12-28T16:36:51.066811Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg132181.blob.core.windows.net/azureml/ExperimentRun/dcid.5791282c-1eef-41a6-9255-d57efda530b0/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=Qb%2F2LjXKLSLBb%2FlZXBAy2iF8y56Qm1AK4YOLAQUHk0Y%3D&st=2020-12-28T15%3A51%3A06Z&se=2020-12-29T00%3A01%3A06Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg132181.blob.core.windows.net/azureml/ExperimentRun/dcid.5791282c-1eef-41a6-9255-d57efda530b0/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=Pe%2Fb1twCyrf53fu1wSWEc%2FGzDX0nUD4GLH0601sW7yY%3D&st=2020-12-28T15%3A51%3A06Z&se=2020-12-29T00%3A01%3A06Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg132181.blob.core.windows.net/azureml/ExperimentRun/dcid.5791282c-1eef-41a6-9255-d57efda530b0/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=iC78DVfkI4yW%2FvShUyiLOpJb8TdLnpO66k7xtxVjbJw%3D&st=2020-12-28T15%3A51%3A06Z&se=2020-12-29T00%3A01%3A06Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/9e4cb178-59ef-419e-8bff-dd3f8f1d45fa/metrics_data
# Downloaded azureml/9e4cb178-59ef-419e-8bff-dd3f8f1d45fa/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_11  \
# precision_score_micro                               [0.7028831562974204]
# weighted_accuracy                                   [0.6777071749487821]
# log_loss                                            [0.4727617100192343]
# f1_score_micro                                      [0.7028831562974204]
# norm_macro_recall                                     [0.60857520741988]
# f1_score_weighted                                   [0.7576462271607428]
# average_precision_score_micro                       [0.8586611512252279]
# AUC_micro                                           [0.8421778525885314]
# average_precision_score_macro                       [0.7437279409593297]
# AUC_macro                                           [0.9001198487719669]
# recall_score_weighted                               [0.7028831562974204]
# recall_score_macro                                    [0.80428760370994]
# balanced_accuracy                                     [0.80428760370994]
# f1_score_macro                                       [0.607238953049555]
# precision_score_macro                               [0.6266772700983227]
# precision_score_weighted                            [0.9070491420567293]
# matthews_correlation                               [0.39266435011462636]
# recall_score_micro                                  [0.7028831562974204]
# accuracy                                            [0.7028831562974204]
# AUC_weighted                                        [0.9001198487719669]
# average_precision_score_weighted                    [0.9317451483575886]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_8  \
# precision_score_micro                              [0.8880121396054628]
# weighted_accuracy                                  [0.9843450583187134]
# log_loss                                           [0.2705162953175455]
# f1_score_micro                                     [0.8880121396054628]
# norm_macro_recall                                                 [0.0]
# f1_score_weighted                                  [0.8353395018439429]
# average_precision_score_micro                       [0.966189041659198]
# AUC_micro                                           [0.965255307047741]
# average_precision_score_macro                      [0.7276467167522513]
# AUC_macro                                            [0.88836512937925]
# recall_score_weighted                              [0.8880121396054628]
# recall_score_macro                                                [0.5]
# balanced_accuracy                                                 [0.5]
# f1_score_macro                                     [0.4703423886834914]
# precision_score_macro                              [0.4440060698027314]
# precision_score_weighted                            [0.788565560086672]
# matthews_correlation                                              [0.0]
# recall_score_micro                                 [0.8880121396054628]
# accuracy                                           [0.8880121396054628]
# AUC_weighted                                         [0.88836512937925]
# average_precision_score_weighted                   [0.9266091614185523]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_16  \
# precision_score_micro                               [0.7047040971168437]
# weighted_accuracy                                   [0.7003048069262952]
# log_loss                                            [0.5496960866155358]
# f1_score_micro                                      [0.7047040971168437]
# norm_macro_recall                                   [0.4448473363749357]
# f1_score_weighted                                   [0.7579320774824435]
# average_precision_score_micro                       [0.7703839246792208]
# AUC_micro                                           [0.8114252292870284]
# average_precision_score_macro                       [0.6947891524063751]
# AUC_macro                                           [0.8024190187219713]
# recall_score_weighted                               [0.7047040971168437]
# recall_score_macro                                  [0.7224236681874678]
# balanced_accuracy                                   [0.7224236681874678]
# f1_score_macro                                      [0.5845512548138593]
# precision_score_macro                               [0.5971984211851311]
# precision_score_weighted                            [0.8757110993587777]
# matthews_correlation                               [0.29406957939934797]
# recall_score_micro                                  [0.7047040971168437]
# accuracy                                            [0.7047040971168437]
# AUC_weighted                                        [0.8024190187219712]
# average_precision_score_weighted                    [0.9013524684315434]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_12  \
# precision_score_micro                               [0.7544764795144158]
# weighted_accuracy                                   [0.7516547310493644]
# log_loss                                            [0.5804590619270027]
# f1_score_micro                                      [0.7544764795144158]
# norm_macro_recall                                   [0.5316839771268527]
# f1_score_weighted                                   [0.7965646689338466]
# average_precision_score_micro                       [0.8498600300029638]
# AUC_micro                                           [0.8455902975262559]
# average_precision_score_macro                       [0.7269655137232618]
# AUC_macro                                            [0.870089580936821]
# recall_score_weighted                               [0.7544764795144158]
# recall_score_macro                                  [0.7658419885634263]
# balanced_accuracy                                   [0.7658419885634263]
# f1_score_macro                                      [0.6302285014756015]
# precision_score_macro                               [0.6239613312925617]
# precision_score_weighted                            [0.8881950874313431]
# matthews_correlation                                 [0.363065431104556]
# recall_score_micro                                  [0.7544764795144158]
# accuracy                                            [0.7544764795144158]
# AUC_weighted                                         [0.870089580936821]
# average_precision_score_weighted                    [0.9246387905367092]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_25  \
# precision_score_micro                               [0.9053110773899848]
# weighted_accuracy                                   [0.9611863544086745]
# log_loss                                           [0.20186836086504387]
# f1_score_micro                                      [0.9053110773899848]
# norm_macro_recall                                   [0.3605104779687578]
# f1_score_weighted                                   [0.8955125918006998]
# average_precision_score_micro                       [0.9768195275122659]
# AUC_micro                                           [0.9756841307816829]
# average_precision_score_macro                       [0.7925979654389392]
# AUC_macro                                           [0.9296004238237872]
# recall_score_weighted                               [0.9053110773899848]
# recall_score_macro                                  [0.6802552389843789]
# balanced_accuracy                                   [0.6802552389843789]
# f1_score_macro                                       [0.713956594323873]
# precision_score_macro                               [0.7749716015055441]
# precision_score_weighted                            [0.8926129851400357]
# matthews_correlation                                [0.4452642889040137]
# recall_score_micro                                  [0.9053110773899848]
# accuracy                                            [0.9053110773899848]
# AUC_weighted                                         [0.929600423823787]
# average_precision_score_weighted                    [0.9464369822739701]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_47  \
# precision_score_micro                               [0.9077389984825494]
# weighted_accuracy                                   [0.9718153332910996]
# log_loss                                            [0.2153276088559062]
# f1_score_micro                                      [0.9077389984825494]
# norm_macro_recall                                  [0.29930146874947905]
# f1_score_weighted                                   [0.8921145847163784]
# average_precision_score_micro                       [0.9748872011336679]
# AUC_micro                                           [0.9736684773222866]
# average_precision_score_macro                       [0.7738392418218227]
# AUC_macro                                           [0.9245786306120067]
# recall_score_weighted                               [0.9077389984825494]
# recall_score_macro                                  [0.6496507343747395]
# balanced_accuracy                                   [0.6496507343747395]
# f1_score_macro                                      [0.6923564547158825]
# precision_score_macro                               [0.8058467444263989]
# precision_score_weighted                              [0.89395580550911]
# matthews_correlation                                [0.4278793751025346]
# recall_score_micro                                  [0.9077389984825494]
# accuracy                                            [0.9077389984825494]
# AUC_weighted                                        [0.9245786306120067]
# average_precision_score_weighted                    [0.9416441715326461]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_4  \
# precision_score_micro                              [0.8880121396054628]
# weighted_accuracy                                  [0.9843450583187134]
# log_loss                                           [0.2709405154368589]
# f1_score_micro                                     [0.8880121396054628]
# norm_macro_recall                                                 [0.0]
# f1_score_weighted                                  [0.8353395018439429]
# average_precision_score_micro                      [0.9644271062387089]
# AUC_micro                                          [0.9636713556430052]
# average_precision_score_macro                      [0.7273259606327476]
# AUC_macro                                          [0.8804012988865364]
# recall_score_weighted                              [0.8880121396054628]
# recall_score_macro                                                [0.5]
# balanced_accuracy                                                 [0.5]
# f1_score_macro                                     [0.4703423886834914]
# precision_score_macro                              [0.4440060698027314]
# precision_score_weighted                            [0.788565560086672]
# matthews_correlation                                              [0.0]
# recall_score_micro                                 [0.8880121396054628]
# accuracy                                           [0.8880121396054628]
# AUC_weighted                                       [0.8804012988865364]
# average_precision_score_weighted                   [0.9253667594208449]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_13  \
# precision_score_micro                               [0.9062215477996965]
# weighted_accuracy                                   [0.9766010009385309]
# log_loss                                           [0.33655623030329523]
# f1_score_micro                                      [0.9062215477996965]
# norm_macro_recall                                  [0.24549085203770704]
# f1_score_weighted                                    [0.885603431576398]
# average_precision_score_micro                       [0.9766643355999638]
# AUC_micro                                           [0.9758990146932517]
# average_precision_score_macro                       [0.7985126174047921]
# AUC_macro                                           [0.9308878256246677]
# recall_score_weighted                               [0.9062215477996965]
# recall_score_macro                                  [0.6227454260188535]
# balanced_accuracy                                   [0.6227454260188535]
# f1_score_macro                                      [0.6650154684677185]
# precision_score_macro                                [0.822098675416211]
# precision_score_weighted                            [0.8929725418691179]
# matthews_correlation                                [0.3976739324324451]
# recall_score_micro                                  [0.9062215477996965]
# accuracy                                            [0.9062215477996965]
# AUC_weighted                                        [0.9308878256246675]
# average_precision_score_weighted                     [0.947605275820125]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_18  \
# precision_score_micro                               [0.7377845220030349]
# weighted_accuracy                                    [0.737267834930338]
# log_loss                                            [0.5856516199603344]
# f1_score_micro                                      [0.7377845220030349]
# norm_macro_recall                                  [0.47973129423707084]
# f1_score_weighted                                   [0.7833013298991601]
# average_precision_score_micro                       [0.8290654885144341]
# AUC_micro                                           [0.8297471913346428]
# average_precision_score_macro                       [0.7339399118290093]
# AUC_macro                                           [0.8510165843285227]
# recall_score_weighted                               [0.7377845220030349]
# recall_score_macro                                  [0.7398656471185354]
# balanced_accuracy                                   [0.7398656471185354]
# f1_score_macro                                      [0.6106210957887861]
# precision_score_macro                               [0.6102595072623206]
# precision_score_weighted                            [0.8799712216477685]
# matthews_correlation                               [0.32525355069820455]
# recall_score_micro                                  [0.7377845220030349]
# accuracy                                            [0.7377845220030349]
# AUC_weighted                                        [0.8510165843285227]
# average_precision_score_weighted                    [0.9227379840974148]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_35  ...  \
# precision_score_micro                               [0.8880121396054628]  ...
# weighted_accuracy                                   [0.9843450583187134]  ...
# log_loss                                           [0.31136044745279967]  ...
# f1_score_micro                                      [0.8880121396054628]  ...
# norm_macro_recall                                                  [0.0]  ...
# f1_score_weighted                                   [0.8353395018439429]  ...
# average_precision_score_micro                       [0.9736443067968061]  ...
# AUC_micro                                           [0.9725403598131164]  ...
# average_precision_score_macro                       [0.7825761605827746]  ...
# AUC_macro                                           [0.9249930998968227]  ...
# recall_score_weighted                               [0.8880121396054628]  ...
# recall_score_macro                                                 [0.5]  ...
# balanced_accuracy                                                  [0.5]  ...
# f1_score_macro                                      [0.4703423886834914]  ...
# precision_score_macro                               [0.4440060698027314]  ...
# precision_score_weighted                             [0.788565560086672]  ...
# matthews_correlation                                               [0.0]  ...
# recall_score_micro                                  [0.8880121396054628]  ...
# accuracy                                            [0.8880121396054628]  ...
# AUC_weighted                                        [0.9249930998968227]  ...
# average_precision_score_weighted                     [0.943523946918008]  ...
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_37  \
# precision_score_micro                               [0.9125948406676783]
# weighted_accuracy                                   [0.9504450461659876]
# log_loss                                            [0.1879296926979376]
# f1_score_micro                                      [0.9125948406676783]
# norm_macro_recall                                   [0.5202816723997725]
# f1_score_weighted                                   [0.9107366491128376]
# average_precision_score_micro                       [0.9797387760522972]
# AUC_micro                                           [0.9787713485047699]
# average_precision_score_macro                       [0.8075693879029218]
# AUC_macro                                            [0.943455275290962]
# recall_score_weighted                               [0.9125948406676783]
# recall_score_macro                                  [0.7601408361998863]
# balanced_accuracy                                   [0.7601408361998863]
# f1_score_macro                                      [0.7709897136502641]
# precision_score_macro                               [0.7832518152480838]
# precision_score_weighted                            [0.9092442403901421]
# matthews_correlation                                [0.5429009636159149]
# recall_score_micro                                  [0.9125948406676783]
# accuracy                                            [0.9125948406676783]
# AUC_weighted                                        [0.9434552752909621]
# average_precision_score_weighted                    [0.9512709076945858]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_43  \
# precision_score_micro                               [0.9116843702579667]
# weighted_accuracy                                    [0.954433600758459]
# log_loss                                             [0.178625258548058]
# f1_score_micro                                      [0.9116843702579667]
# norm_macro_recall                                   [0.4789959006903808]
# f1_score_weighted                                   [0.9079045862731869]
# average_precision_score_micro                       [0.9805323016444578]
# AUC_micro                                           [0.9795755282869847]
# average_precision_score_macro                       [0.8135300428192275]
# AUC_macro                                           [0.9448362221147844]
# recall_score_weighted                               [0.9116843702579667]
# recall_score_macro                                  [0.7394979503451904]
# balanced_accuracy                                   [0.7394979503451904]
# f1_score_macro                                      [0.7592136993642365]
# precision_score_macro                               [0.7843888023720283]
# precision_score_weighted                            [0.9055256714023016]
# matthews_correlation                                 [0.521959903706115]
# recall_score_micro                                  [0.9116843702579667]
# accuracy                                            [0.9116843702579667]
# AUC_weighted                                        [0.9448362221147845]
# average_precision_score_weighted                     [0.952784356712131]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_45  \
# precision_score_micro                               [0.9141122913505311]
# weighted_accuracy                                   [0.9556549669755132]
# log_loss                                           [0.17886731319594343]
# f1_score_micro                                      [0.9141122913505311]
# norm_macro_recall                                  [0.49357132669071047]
# f1_score_weighted                                    [0.910561588444628]
# average_precision_score_micro                       [0.9808265447336563]
# AUC_micro                                           [0.9798923738316896]
# average_precision_score_macro                       [0.8199994577810349]
# AUC_macro                                           [0.9452150331482809]
# recall_score_weighted                               [0.9141122913505311]
# recall_score_macro                                  [0.7467856633453552]
# balanced_accuracy                                   [0.7467856633453552]
# f1_score_macro                                      [0.7664481387558311]
# precision_score_macro                               [0.7913219932781856]
# precision_score_weighted                             [0.908345769711651]
# matthews_correlation                                [0.5362614711435016]
# recall_score_micro                                  [0.9141122913505311]
# accuracy                                            [0.9141122913505311]
# AUC_weighted                                         [0.945215033148281]
# average_precision_score_weighted                    [0.9542563564642611]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_33  \
# precision_score_micro                               [0.9159332321699545]
# weighted_accuracy                                   [0.9550275551853912]
# log_loss                                           [0.17788346285786574]
# f1_score_micro                                      [0.9159332321699545]
# norm_macro_recall                                   [0.5169362800941748]
# f1_score_weighted                                   [0.9131760047232391]
# average_precision_score_micro                       [0.9809272175719745]
# AUC_micro                                           [0.9799944275710886]
# average_precision_score_macro                       [0.8186176268448488]
# AUC_macro                                           [0.9463227544100459]
# recall_score_weighted                               [0.9159332321699545]
# recall_score_macro                                  [0.7584681400470874]
# balanced_accuracy                                   [0.7584681400470874]
# f1_score_macro                                      [0.7749361894045931]
# precision_score_macro                               [0.7947825361313043]
# precision_score_weighted                            [0.9112858568424094]
# matthews_correlation                                [0.5520575833451492]
# recall_score_micro                                  [0.9159332321699545]
# accuracy                                            [0.9159332321699545]
# AUC_weighted                                         [0.946322754410046]
# average_precision_score_weighted                    [0.9540769305581739]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_38  \
# precision_score_micro                               [0.8946889226100152]
# weighted_accuracy                                   [0.9570555772792082]
# log_loss                                           [0.22339957520980902]
# f1_score_micro                                      [0.8946889226100152]
# norm_macro_recall                                  [0.28697390186478766]
# f1_score_weighted                                   [0.8820482770933484]
# average_precision_score_micro                       [0.9718235317151882]
# AUC_micro                                           [0.9703370858959982]
# average_precision_score_macro                       [0.7452186004346228]
# AUC_macro                                           [0.9148027126204277]
# recall_score_weighted                               [0.8946889226100152]
# recall_score_macro                                  [0.6434869509323938]
# balanced_accuracy                                   [0.6434869509323938]
# f1_score_macro                                      [0.6735184023442062]
# precision_score_macro                               [0.7349674065041389]
# precision_score_weighted                             [0.877418720310461]
# matthews_correlation                                 [0.367231571234126]
# recall_score_micro                                  [0.8946889226100152]
# accuracy                                            [0.8946889226100152]
# AUC_weighted                                        [0.9148027126204277]
# average_precision_score_weighted                    [0.9343240280148656]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_14  \
# precision_score_micro                               [0.8880121396054628]
# weighted_accuracy                                   [0.9843450583187134]
# log_loss                                            [0.2457262373052826]
# f1_score_micro                                      [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# average_precision_score_micro                       [0.9681538292439326]
# AUC_micro                                           [0.9690054135456074]
# average_precision_score_macro                        [0.756237739559782]
# AUC_macro                                           [0.9072200086320754]
# recall_score_weighted                               [0.8880121396054628]
# recall_score_macro                                                 [0.5]
# balanced_accuracy                                                  [0.5]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_macro                               [0.4440060698027314]
# precision_score_weighted                             [0.788565560086672]
# matthews_correlation                                               [0.0]
# recall_score_micro                                  [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# AUC_weighted                                        [0.9072200086320754]
# average_precision_score_weighted                    [0.9335966556914297]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_34  \
# precision_score_micro                               [0.9077389984825494]
# weighted_accuracy                                   [0.9574099263972502]
# log_loss                                            [0.1936080531599622]
# f1_score_micro                                      [0.9077389984825494]
# norm_macro_recall                                  [0.41534638517950473]
# f1_score_weighted                                   [0.9011309879305923]
# average_precision_score_micro                        [0.978122036830583]
# AUC_micro                                           [0.9770333033220426]
# average_precision_score_macro                       [0.7974711095170728]
# AUC_macro                                           [0.9356632527364235]
# recall_score_weighted                               [0.9077389984825494]
# recall_score_macro                                  [0.7076731925897524]
# balanced_accuracy                                   [0.7076731925897524]
# f1_score_macro                                      [0.7354772332114344]
# precision_score_macro                               [0.7773409476595471]
# precision_score_weighted                            [0.8981043724891076]
# matthews_correlation                               [0.47998449990109276]
# recall_score_micro                                  [0.9077389984825494]
# accuracy                                            [0.9077389984825494]
# AUC_weighted                                        [0.9356632527364235]
# average_precision_score_weighted                    [0.9482070684582469]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_36  \
# precision_score_micro                               [0.9132018209408195]
# weighted_accuracy                                    [0.954939715235299]
# log_loss                                           [0.18012736943904312]
# f1_score_micro                                      [0.9132018209408195]
# norm_macro_recall                                  [0.49017777259112316]
# f1_score_weighted                                   [0.9096764096913943]
# average_precision_score_micro                       [0.9805583578526404]
# AUC_micro                                           [0.9795984627464707]
# average_precision_score_macro                       [0.8198704441305439]
# AUC_macro                                           [0.9442592067752529]
# recall_score_weighted                               [0.9132018209408195]
# recall_score_macro                                  [0.7450888862955616]
# balanced_accuracy                                   [0.7450888862955616]
# f1_score_macro                                      [0.7642816263884915]
# precision_score_macro                               [0.7884731106837775]
# precision_score_weighted                            [0.9074329436294158]
# matthews_correlation                                [0.5317952742313653]
# recall_score_micro                                  [0.9132018209408195]
# accuracy                                            [0.9132018209408195]
# AUC_weighted                                         [0.944259206775253]
# average_precision_score_weighted                    [0.9541411484948241]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_39  \
# precision_score_micro                               [0.9104704097116844]
# weighted_accuracy                                   [0.9530879479104497]
# log_loss                                           [0.18600765802920322]
# f1_score_micro                                      [0.9104704097116844]
# norm_macro_recall                                    [0.477628846691748]
# f1_score_weighted                                   [0.9068987545099138]
# average_precision_score_micro                       [0.9797562823129949]
# AUC_micro                                           [0.9787503482768071]
# average_precision_score_macro                       [0.8129801475093046]
# AUC_macro                                           [0.9410393129905326]
# recall_score_weighted                               [0.9104704097116844]
# recall_score_macro                                   [0.738814423345874]
# balanced_accuracy                                    [0.738814423345874]
# f1_score_macro                                      [0.7571819946586409]
# precision_score_macro                               [0.7802691533441449]
# precision_score_weighted                             [0.904541125173857]
# matthews_correlation                                [0.5174256129629391]
# recall_score_micro                                  [0.9104704097116844]
# accuracy                                            [0.9104704097116844]
# AUC_weighted                                        [0.9410393129905327]
# average_precision_score_weighted                    [0.9522580543753243]
#
#                                  9e4cb178-59ef-419e-8bff-dd3f8f1d45fa_23
# precision_score_micro                               [0.9077389984825494]
# weighted_accuracy                                   [0.9553520111267004]
# log_loss                                            [0.1880124255406952]
# f1_score_micro                                      [0.9077389984825494]
# norm_macro_recall                                   [0.4319242303837938]
# f1_score_weighted                                   [0.9021770532058848]
# average_precision_score_micro                       [0.9790992488308239]
# AUC_micro                                           [0.9780497880404623]
# average_precision_score_macro                       [0.8072509489251203]
# AUC_macro                                           [0.9389373285393825]
# recall_score_weighted                               [0.9077389984825494]
# recall_score_macro                                  [0.7159621151918969]
# balanced_accuracy                                   [0.7159621151918969]
# f1_score_macro                                      [0.7405646205646206]
# precision_score_macro                               [0.7753142511695126]
# precision_score_weighted                            [0.8992110967163239]
# matthews_correlation                               [0.48767795941601105]
# recall_score_micro                                  [0.9077389984825494]
# accuracy                                            [0.9077389984825494]
# AUC_weighted                                        [0.9389373285393824]
# average_precision_score_weighted                     [0.950761405989792]
#
# [21 rows x 51 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/9e4cb178-59ef-419e-8bff-dd3f8f1d45fa/model_data
# Downloaded azureml/9e4cb178-59ef-419e-8bff-dd3f8f1d45fa/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                  subsample=0.5942105263157895,
#                                                                                                                                  subsample_for_bin=200000,
#                                                                                                                                  subsample_freq=0,
#                                                                                                                                  verbose=-10))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.2727272727272727,
#                                                                                          0.09090909090909091,
#                                                                                          0.09090909090909091,
#                                                                                          0.09090909090909091,
#                                                                                          0.09090909090909091,
#                                                                                          0.09090909090909091,
#                                                                                          0.18181818181818182,
#                                                                                          0.09090909090909091]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('33',
#                                              Pipeline(memory=None,
#                                                       steps=[('standardscalerwrapper',
#                                                               <azureml.automl.runtime.shared.model_wrappers.StandardScalerWrapper object at 0x7f517c5d6630>),
#                                                              ('xgboostclassifier',
#                                                               XGBoostClassifier(base_score=0.5,
#                                                                                 booster='gbtree',
#                                                                                 colsample_bylevel=1,
#                                                                                 colsample_bynode=1,
#                                                                                 colsample_bytree=1,
#                                                                                 e...
#                                                                                  reg_alpha=0.3684210526315789,
#                                                                                  reg_lambda=0.7894736842105263,
#                                                                                  silent=True,
#                                                                                  subsample=0.5942105263157895,
#                                                                                  subsample_for_bin=200000,
#                                                                                  subsample_freq=0,
#                                                                                  verbose=-10))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.2727272727272727, 0.09090909090909091,
#                                          0.09090909090909091, 0.09090909090909091,
#                                          0.09090909090909091, 0.09090909090909091,
#                                          0.18181818181818182,
#                                          0.09090909090909091]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_87349222_492c_11eb_b9b7_000d3aebd03brow0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_87349222_492c_11eb_b9b7_000d3aebd03brow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_87349222_492c_11eb_b9b7_000d3aebd03brow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_87349222_492c_11eb_b9b7_000d3aebd03brow1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_87349222_492c_11eb_b9b7_000d3aebd03b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_87349222_492c_11eb_b9b7_000d3aebd03blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_87349222_492c_11eb_b9b7_000d3aebd03brow0_col0" class="data row0 col0" >28786</td>
#                         <td id="T_87349222_492c_11eb_b9b7_000d3aebd03brow0_col1" class="data row0 col1" >472</td>
#             </tr>
#             <tr>
#                         <th id="T_87349222_492c_11eb_b9b7_000d3aebd03blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_87349222_492c_11eb_b9b7_000d3aebd03brow1_col0" class="data row1 col0" >1148</td>
#                         <td id="T_87349222_492c_11eb_b9b7_000d3aebd03brow1_col1" class="data row1 col1" >2544</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 13f2091a-a603-4755-8dcf-acccd5727299,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/b968fb36-f06a-4c76-a15f-afab68ae7667/resourceGroups/aml-quickstarts-132181/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-132181/PipelineRuns/PipelineSubmit/13f2091a-a603-4755-8dcf-acccd5727299)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  771cc108-1ed3-48eb-a9ea-f2a5c53662f2

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
